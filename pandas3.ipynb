# %% [markdown]
# <a href="https://colab.research.google.com/github/sinchana-km/pandas/blob/main/pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b778da20-92dd-42ed-b059-313092e456bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b778da20-92dd-42ed-b059-313092e456bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import glob

files = glob.glob("*.csv")

df = pd.concat([pd.read_csv(file) for file in files], ignore_index=True)

df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %%
df.to_csv("merged_file.csv", index=False)

# %%
df = pd.read_csv("merged_file.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %% [markdown]
# Augment data with additional columns
#
# task2: Add month column

# %%
df['Month'] = df['Order Date'].str[0:2]
df['Month'] = df['Month'].astype('int32')
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301      3  700.00
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301      3   14.95
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301      3   23.98
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016      3   99.99
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016      3  379.99

# %% [markdown]
# clean up data

# %% [markdown]
# drop rows of NAN

# %%
nan_df = df[df.isna().any(axis=1)]
nan_df.head()

df = df.dropna(how='all')
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016

# %% [markdown]
# Find 'or' and delete it

# %%
df[df['Quantity Ordered'] == 'Quantity Ordered']
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 433     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 864     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 930     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1979    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2032    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 185203  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185843  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186236  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186336  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186448  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address Month
# 433     Purchase Address    Or
# 864     Purchase Address    Or
# 930     Purchase Address    Or
# ...

# %%
df = df[df['Quantity Ordered'] != 'Quantity Ordered']

# %% [markdown]
# converts columns to corect type

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
df['Price Each'] = pd.to_numeric(df['Price Each'])
df.head()
# Out:
# /tmp/ipykernel_520/1443175188.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
# /tmp/ipykernel_520/1443175188.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price Each'] = pd.to_numeric(df['Price Each'])
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# ...

# %%
df = df[df['Order Date'] != 'Order Date']

# %%
df['Month'] = df['Order Date'].str[0:2]
df['Month'] = df['Month'].astype('int32')

df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#        Order Date                      Purchase Address  Month
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301      3
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301      3
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301      3
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016      3
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016      3

# %% [markdown]
# Task3:Add a sales column

# %%
df['Sales'] = df['Quantity Ordered']*df['Price Each']
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301      3  700.00
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301      3   14.95
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301      3   23.98
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016      3   99.99
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016      3  379.99

# %% [markdown]
# 1. whta was the best month for sales? How much was earned that month

# %%
results = df.groupby('Month').sum()

# %%
import matplotlib.pyplot as plt
months = range(1,13)
plt.bar(months,results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()

# %% [markdown]
# 2. What city had the highest number of sales

# %% [markdown]
# Task4: Add city column

# %%
df['Column'] = df['Purchase Address'].apply(lambda x: x.split(',')[1])
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   162009                      iPhone                 1      700.00
# 1   162009    Lightning Charging Cable                 1       14.95
# 2   162009            Wired Headphones                 2       11.99
# 3   162010  Bose SoundSport Headphones                 1       99.99
# 4   162011      34in Ultrawide Monitor                 1      379.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301      3  700.00
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301      3   14.95
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301      3   23.98
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016      3   99.99
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016      3  379.99
#
#            Column
# 0          Austin
# 1          Austin
# 2          Austin
# 3   San Francisco
# 4   San Francisco

# %%
df['Month'] = df['Order Date'].str[0:2]
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   162009                      iPhone                1        700
# 1   162009    Lightning Charging Cable                1      14.95
# 2   162009            Wired Headphones                2      11.99
# 3   162010  Bose SoundSport Headphones                1      99.99
# 4   162011      34in Ultrawide Monitor                1     379.99
#
#        Order Date                      Purchase Address Month
# 0  03/28/19 20:59       942 Church St, Austin, TX 73301    03
# 1  03/28/19 20:59       942 Church St, Austin, TX 73301    03
# 2  03/28/19 20:59       942 Church St, Austin, TX 73301    03
# 3  03/17/19 05:39  261 10th St, San Francisco, CA 94016    03
# 4  03/10/19 00:01  764 13th St, San Francisco, CA 94016    03
